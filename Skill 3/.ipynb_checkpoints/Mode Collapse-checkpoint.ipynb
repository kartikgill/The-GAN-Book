# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook
# %matplotlib inline

# %%
import tensorflow
print (tensorflow.__version__)
# Out:
# 2.3.1

# %%
from tensorflow.keras.datasets import mnist

(trainX, trainY), (testX, testY) = mnist.load_data()

print('Training data shapes: X=%s, y=%s' % (trainX.shape, trainY.shape))
print('Testing data shapes: X=%s, y=%s' % (testX.shape, testY.shape))

plt.figure(figsize=(7, 7))
for j in range(9):
    i = np.random.randint(0, 10000)
    plt.subplot(330 + 1 + j)
    plt.imshow(trainX[i], cmap='gray')
    plt.title(trainY[i])
plt.show()
# Out:
# Training data shapes: X=(60000, 28, 28), y=(60000,)
# Testing data shapes: X=(10000, 28, 28), y=(10000,)

# %%
trainX = [image/255.0 for image in trainX]
testX = [image/255.0 for image in testX]

trainX = np.reshape(trainX, (60000, 28, 28, 1))
testX = np.reshape(testX, (10000, 28, 28, 1))

print (trainX.shape, testX.shape, trainY.shape, testY.shape)
# Out:
# (60000, 28, 28, 1) (10000, 28, 28, 1) (60000,) (10000,)

# %% [markdown]
# # Generator Model

# %%
random_input = tensorflow.keras.layers.Input(shape = 50)

x = tensorflow.keras.layers.Dense(512, activation='relu')(random_input)
x = tensorflow.keras.layers.Dense(28*28)(x)
x = tensorflow.keras.layers.Reshape((28, 28, 1))(x)

generated_image = tensorflow.keras.layers.Activation('sigmoid')(x)

generator_network = tensorflow.keras.models.Model(inputs=random_input, outputs=generated_image)
generator_network.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 50)]              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               26112
# _________________________________________________________________
# dense_1 (Dense)              (None, 784)               402192
# _________________________________________________________________
# reshape (Reshape)            (None, 28, 28, 1)         0
# _________________________________________________________________
# activation (Activation)      (None, 28, 28, 1)         0
# =================================================================
# Total params: 428,304
# Trainable params: 428,304
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Discriminator

# %%
image_input = tensorflow.keras.layers.Input(shape=(28, 28, 1))

x = tensorflow.keras.layers.Flatten()(image_input)
x = tensorflow.keras.layers.Dense(128)(x)
x = tensorflow.keras.layers.Dense(1)(x)

real_vs_fake_output = tensorflow.keras.layers.Activation('sigmoid')(x)

discriminator_network = tensorflow.keras.models.Model(inputs=image_input, outputs=real_vs_fake_output)
discriminator_network.summary()
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               100480
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 100,609
# Trainable params: 100,609
# Non-trainable params: 0
# _________________________________________________________________

# %%
adam_optimizer = tensorflow.keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.5)
discriminator_network.compile(loss='binary_crossentropy', optimizer=adam_optimizer, metrics=['accuracy'])

# %% [markdown]
# # GAN

# %%
discriminator_network.trainable=False

gan_input = generator_network(random_input)
gan_output = discriminator_network(gan_input)

gan_model = tensorflow.keras.models.Model(random_input, gan_output)
gan_model.summary()
# Out:
# Model: "functional_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 50)]              0
# _________________________________________________________________
# functional_1 (Functional)    (None, 28, 28, 1)         428304
# _________________________________________________________________
# functional_3 (Functional)    (None, 1)                 100609
# =================================================================
# Total params: 528,913
# Trainable params: 428,304
# Non-trainable params: 100,609
# _________________________________________________________________

# %% [markdown]
# # Compiling Models

# %%
gan_model.compile(loss='binary_crossentropy', optimizer=adam_optimizer)

# %% [markdown]
# # Define Data Generators

# %%
# Indices of Zero Images
#indices = list(np.where(trainY==0)[0])
indices = [i for i in range(60000)]

def get_random_noise(batch_size, noise_size):
    random_values = np.random.randn(batch_size*noise_size)
    random_noise_batch = np.reshape(random_values, (batch_size, noise_size))
    return random_noise_batch

def get_fake_samples(generator_network, batch_size, noise_size):
    random_noise_batch = get_random_noise(batch_size, noise_size) 
    fake_samples = generator_network.predict_on_batch(random_noise_batch)
    return fake_samples

def get_real_samples(batch_size):
    random_indices = np.random.choice(indices, size=batch_size)
    real_images = trainX[np.array(random_indices),:]
    return real_images

def show_generator_results(generator_network):
    fake_samples = get_fake_samples(generator_network, 10, noise_size)

    plt.figure(figsize=(7, 7))
    for j in range(9):
        i = j
        plt.subplot(330 + 1 + j)
        plt.imshow(fake_samples[i,:,:,-1], cmap='gray')
    plt.show()
    return

# %% [markdown]
# # Training GAN

# %%
epochs = 50
batch_size = 100
steps = 500
noise_size = 50

losses_d = []
losses_g = []

for i in range(0, epochs):
    if (i%5 == 0):
        show_generator_results(generator_network)
    for j in range(steps):
        fake_samples = get_fake_samples(generator_network, batch_size//2, noise_size)
        real_samples = get_real_samples(batch_size=batch_size//2)

        fake_y = np.zeros((batch_size//2, 1))
        real_y = np.ones((batch_size//2, 1))
        
        input_batch = np.vstack((fake_samples, real_samples))
        output_labels = np.vstack((fake_y, real_y))
        
        # Updating Discriminator weights
        discriminator_network.trainable=True
        loss_d = discriminator_network.train_on_batch(input_batch, output_labels)
        
        gan_input = get_random_noise(batch_size, noise_size)
        
        # Make the Discriminator belive that these are real samples and calculate loss to train the generator
        gan_output = np.ones((batch_size))
        
        # Updating Generator weights
        discriminator_network.trainable=False
        loss_g = gan_model.train_on_batch(gan_input, gan_output)
        
        losses_d.append(loss_d[0])
        losses_g.append(loss_g)
        
        if j%50 == 0:
            print ("Epoch:%.0f, Step:%.0f, D-Loss:%.3f, D-Acc:%.3f, G-Loss:%.3f"%(i,j,loss_d[0],loss_d[1]*100,loss_g))
# Out:
# Epoch:0, Step:0, D-Loss:0.935, D-Acc:17.000, G-Loss:0.699
# Epoch:0, Step:50, D-Loss:0.145, D-Acc:99.000, G-Loss:2.888
# Epoch:0, Step:100, D-Loss:0.107, D-Acc:100.000, G-Loss:3.224
# Epoch:0, Step:150, D-Loss:0.123, D-Acc:99.000, G-Loss:2.817
# Epoch:0, Step:200, D-Loss:0.204, D-Acc:98.000, G-Loss:2.498
# Epoch:0, Step:250, D-Loss:0.350, D-Acc:95.000, G-Loss:2.050
# Epoch:0, Step:300, D-Loss:0.423, D-Acc:88.000, G-Loss:1.489
# Epoch:0, Step:350, D-Loss:0.420, D-Acc:82.000, G-Loss:1.720
# Epoch:0, Step:400, D-Loss:0.434, D-Acc:87.000, G-Loss:1.512
# Epoch:0, Step:450, D-Loss:0.446, D-Acc:84.000, G-Loss:1.423
# Epoch:1, Step:0, D-Loss:0.456, D-Acc:83.000, G-Loss:1.399
# Epoch:1, Step:50, D-Loss:0.447, D-Acc:86.000, G-Loss:1.466
# Epoch:1, Step:100, D-Loss:0.481, D-Acc:81.000, G-Loss:1.303
# Epoch:1, Step:150, D-Loss:0.480, D-Acc:88.000, G-Loss:1.326
# Epoch:1, Step:200, D-Loss:0.458, D-Acc:89.000, G-Loss:1.239
# Epoch:1, Step:250, D-Loss:0.498, D-Acc:83.000, G-Loss:1.209
# Epoch:1, Step:300, D-Loss:0.600, D-Acc:73.000, G-Loss:0.983
# Epoch:1, Step:350, D-Loss:0.720, D-Acc:63.000, G-Loss:0.857
# Epoch:1, Step:400, D-Loss:0.668, D-Acc:62.000, G-Loss:0.805
# Epoch:1, Step:450, D-Loss:0.735, D-Acc:45.000, G-Loss:0.691
# Epoch:2, Step:0, D-Loss:0.878, D-Acc:25.000, G-Loss:0.543
# Epoch:2, Step:50, D-Loss:0.769, D-Acc:32.000, G-Loss:0.531
# Epoch:2, Step:100, D-Loss:0.790, D-Acc:35.000, G-Loss:0.510
# Epoch:2, Step:150, D-Loss:0.802, D-Acc:36.000, G-Loss:0.486
# Epoch:2, Step:200, D-Loss:0.809, D-Acc:37.000, G-Loss:0.461
# Epoch:2, Step:250, D-Loss:0.827, D-Acc:36.000, G-Loss:0.442
# Epoch:2, Step:300, D-Loss:0.766, D-Acc:36.000, G-Loss:0.507
# Epoch:2, Step:350, D-Loss:0.781, D-Acc:38.000, G-Loss:0.473
# Epoch:2, Step:400, D-Loss:0.769, D-Acc:37.000, G-Loss:0.488
# Epoch:2, Step:450, D-Loss:0.762, D-Acc:39.000, G-Loss:0.501
# Epoch:3, Step:0, D-Loss:0.703, D-Acc:44.000, G-Loss:0.529
# Epoch:3, Step:50, D-Loss:0.699, D-Acc:46.000, G-Loss:0.554
# Epoch:3, Step:100, D-Loss:0.678, D-Acc:44.000, G-Loss:0.583
# Epoch:3, Step:150, D-Loss:0.685, D-Acc:42.000, G-Loss:0.601
# Epoch:3, Step:200, D-Loss:0.687, D-Acc:41.000, G-Loss:0.576
# Epoch:3, Step:250, D-Loss:0.679, D-Acc:40.000, G-Loss:0.612
# Epoch:3, Step:300, D-Loss:0.634, D-Acc:46.000, G-Loss:0.635
# Epoch:3, Step:350, D-Loss:0.705, D-Acc:39.000, G-Loss:0.603
# Epoch:3, Step:400, D-Loss:0.614, D-Acc:63.000, G-Loss:0.725
# Epoch:3, Step:450, D-Loss:0.611, D-Acc:49.000, G-Loss:0.703
# Epoch:4, Step:0, D-Loss:0.707, D-Acc:34.000, G-Loss:0.673
# Epoch:4, Step:50, D-Loss:0.707, D-Acc:42.000, G-Loss:0.688
# Epoch:4, Step:100, D-Loss:0.733, D-Acc:35.000, G-Loss:0.694
# Epoch:4, Step:150, D-Loss:0.632, D-Acc:74.000, G-Loss:0.809
# Epoch:4, Step:200, D-Loss:0.680, D-Acc:61.000, G-Loss:0.749
# Epoch:4, Step:250, D-Loss:0.689, D-Acc:58.000, G-Loss:0.779
# Epoch:4, Step:300, D-Loss:0.734, D-Acc:38.000, G-Loss:0.710
# Epoch:4, Step:350, D-Loss:0.732, D-Acc:43.000, G-Loss:0.740
# Epoch:4, Step:400, D-Loss:0.670, D-Acc:71.000, G-Loss:0.854
# Epoch:4, Step:450, D-Loss:0.718, D-Acc:57.000, G-Loss:0.804
# Epoch:5, Step:0, D-Loss:0.726, D-Acc:53.000, G-Loss:0.769
# Epoch:5, Step:50, D-Loss:0.698, D-Acc:50.000, G-Loss:0.788
# Epoch:5, Step:100, D-Loss:0.695, D-Acc:66.000, G-Loss:0.816
# Epoch:5, Step:150, D-Loss:0.716, D-Acc:65.000, G-Loss:0.868
# Epoch:5, Step:200, D-Loss:0.669, D-Acc:68.000, G-Loss:0.848
# Epoch:5, Step:250, D-Loss:0.724, D-Acc:60.000, G-Loss:0.823
# Epoch:5, Step:300, D-Loss:0.692, D-Acc:67.000, G-Loss:0.834
# Epoch:5, Step:350, D-Loss:0.725, D-Acc:61.000, G-Loss:0.814
# Epoch:5, Step:400, D-Loss:0.748, D-Acc:53.000, G-Loss:0.803
# Epoch:5, Step:450, D-Loss:0.666, D-Acc:66.000, G-Loss:0.869
# Epoch:6, Step:0, D-Loss:0.693, D-Acc:66.000, G-Loss:0.828
# Epoch:6, Step:50, D-Loss:0.663, D-Acc:74.000, G-Loss:0.878
# Epoch:6, Step:100, D-Loss:0.665, D-Acc:75.000, G-Loss:0.854
# Epoch:6, Step:150, D-Loss:0.714, D-Acc:60.000, G-Loss:0.800
# Epoch:6, Step:200, D-Loss:0.663, D-Acc:66.000, G-Loss:0.825
# Epoch:6, Step:250, D-Loss:0.727, D-Acc:58.000, G-Loss:0.810
# Epoch:6, Step:300, D-Loss:0.661, D-Acc:68.000, G-Loss:0.804
# Epoch:6, Step:350, D-Loss:0.667, D-Acc:68.000, G-Loss:0.827
# Epoch:6, Step:400, D-Loss:0.739, D-Acc:57.000, G-Loss:0.772
# Epoch:6, Step:450, D-Loss:0.695, D-Acc:58.000, G-Loss:0.762
# Epoch:7, Step:0, D-Loss:0.680, D-Acc:58.000, G-Loss:0.767
# Epoch:7, Step:50, D-Loss:0.724, D-Acc:61.000, G-Loss:0.762
# Epoch:7, Step:100, D-Loss:0.672, D-Acc:61.000, G-Loss:0.759
# Epoch:7, Step:150, D-Loss:0.734, D-Acc:35.000, G-Loss:0.672
# Epoch:7, Step:200, D-Loss:0.739, D-Acc:37.000, G-Loss:0.712
# Epoch:7, Step:250, D-Loss:0.700, D-Acc:56.000, G-Loss:0.766
# Epoch:7, Step:300, D-Loss:0.693, D-Acc:48.000, G-Loss:0.717
# Epoch:7, Step:350, D-Loss:0.712, D-Acc:46.000, G-Loss:0.724
# Epoch:7, Step:400, D-Loss:0.693, D-Acc:48.000, G-Loss:0.703
# Epoch:7, Step:450, D-Loss:0.732, D-Acc:35.000, G-Loss:0.673
# Epoch:8, Step:0, D-Loss:0.685, D-Acc:37.000, G-Loss:0.688
# Epoch:8, Step:50, D-Loss:0.712, D-Acc:40.000, G-Loss:0.711
# Epoch:8, Step:100, D-Loss:0.743, D-Acc:28.000, G-Loss:0.682
# Epoch:8, Step:150, D-Loss:0.761, D-Acc:21.000, G-Loss:0.665
# Epoch:8, Step:200, D-Loss:0.619, D-Acc:81.000, G-Loss:0.819
# Epoch:8, Step:250, D-Loss:0.675, D-Acc:63.000, G-Loss:0.761
# Epoch:8, Step:300, D-Loss:0.727, D-Acc:34.000, G-Loss:0.673
# Epoch:8, Step:350, D-Loss:0.777, D-Acc:26.000, G-Loss:0.674
# Epoch:8, Step:400, D-Loss:0.668, D-Acc:58.000, G-Loss:0.759
# Epoch:8, Step:450, D-Loss:0.662, D-Acc:66.000, G-Loss:0.796
# Epoch:9, Step:0, D-Loss:0.730, D-Acc:35.000, G-Loss:0.706
# Epoch:9, Step:50, D-Loss:0.751, D-Acc:44.000, G-Loss:0.725
# Epoch:9, Step:100, D-Loss:0.651, D-Acc:72.000, G-Loss:0.801
# Epoch:9, Step:150, D-Loss:0.726, D-Acc:43.000, G-Loss:0.735
# Epoch:9, Step:200, D-Loss:0.689, D-Acc:61.000, G-Loss:0.773
# Epoch:9, Step:250, D-Loss:0.687, D-Acc:56.000, G-Loss:0.719
# Epoch:9, Step:300, D-Loss:0.684, D-Acc:59.000, G-Loss:0.777
# Epoch:9, Step:350, D-Loss:0.686, D-Acc:54.000, G-Loss:0.775
# Epoch:9, Step:400, D-Loss:0.726, D-Acc:48.000, G-Loss:0.726
# Epoch:9, Step:450, D-Loss:0.751, D-Acc:52.000, G-Loss:0.747
# Epoch:10, Step:0, D-Loss:0.676, D-Acc:65.000, G-Loss:0.801
# Epoch:10, Step:50, D-Loss:0.659, D-Acc:72.000, G-Loss:0.818
# Epoch:10, Step:100, D-Loss:0.747, D-Acc:36.000, G-Loss:0.725
# Epoch:10, Step:150, D-Loss:0.684, D-Acc:48.000, G-Loss:0.721
# Epoch:10, Step:200, D-Loss:0.695, D-Acc:46.000, G-Loss:0.746
# Epoch:10, Step:250, D-Loss:0.700, D-Acc:52.000, G-Loss:0.754
# Epoch:10, Step:300, D-Loss:0.716, D-Acc:43.000, G-Loss:0.737
# Epoch:10, Step:350, D-Loss:0.755, D-Acc:39.000, G-Loss:0.720
# Epoch:10, Step:400, D-Loss:0.687, D-Acc:52.000, G-Loss:0.751
# Epoch:10, Step:450, D-Loss:0.637, D-Acc:69.000, G-Loss:0.791
# Epoch:11, Step:0, D-Loss:0.734, D-Acc:37.000, G-Loss:0.722
# Epoch:11, Step:50, D-Loss:0.713, D-Acc:43.000, G-Loss:0.721
# Epoch:11, Step:100, D-Loss:0.714, D-Acc:52.000, G-Loss:0.762
# Epoch:11, Step:150, D-Loss:0.743, D-Acc:37.000, G-Loss:0.738
# Epoch:11, Step:200, D-Loss:0.697, D-Acc:48.000, G-Loss:0.733
# Epoch:11, Step:250, D-Loss:0.703, D-Acc:49.000, G-Loss:0.723
# Epoch:11, Step:300, D-Loss:0.755, D-Acc:39.000, G-Loss:0.722
# Epoch:11, Step:350, D-Loss:0.716, D-Acc:46.000, G-Loss:0.710
# Epoch:11, Step:400, D-Loss:0.694, D-Acc:57.000, G-Loss:0.765
# Epoch:11, Step:450, D-Loss:0.720, D-Acc:57.000, G-Loss:0.758
# Epoch:12, Step:0, D-Loss:0.693, D-Acc:62.000, G-Loss:0.781
# Epoch:12, Step:50, D-Loss:0.711, D-Acc:43.000, G-Loss:0.739
# Epoch:12, Step:100, D-Loss:0.729, D-Acc:46.000, G-Loss:0.737
# Epoch:12, Step:150, D-Loss:0.706, D-Acc:54.000, G-Loss:0.746
# Epoch:12, Step:200, D-Loss:0.701, D-Acc:43.000, G-Loss:0.736
# Epoch:12, Step:250, D-Loss:0.654, D-Acc:70.000, G-Loss:0.777
# Epoch:12, Step:300, D-Loss:0.749, D-Acc:32.000, G-Loss:0.710
# Epoch:12, Step:350, D-Loss:0.770, D-Acc:27.000, G-Loss:0.699
# Epoch:12, Step:400, D-Loss:0.709, D-Acc:48.000, G-Loss:0.741
# Epoch:12, Step:450, D-Loss:0.682, D-Acc:66.000, G-Loss:0.795
# Epoch:13, Step:0, D-Loss:0.616, D-Acc:78.000, G-Loss:0.813
# Epoch:13, Step:50, D-Loss:0.708, D-Acc:53.000, G-Loss:0.725
# Epoch:13, Step:100, D-Loss:0.709, D-Acc:36.000, G-Loss:0.690
# Epoch:13, Step:150, D-Loss:0.732, D-Acc:48.000, G-Loss:0.741
# Epoch:13, Step:200, D-Loss:0.646, D-Acc:73.000, G-Loss:0.804
# Epoch:13, Step:250, D-Loss:0.648, D-Acc:76.000, G-Loss:0.789
# Epoch:13, Step:300, D-Loss:0.775, D-Acc:39.000, G-Loss:0.710
# Epoch:13, Step:350, D-Loss:0.765, D-Acc:24.000, G-Loss:0.675
# Epoch:13, Step:400, D-Loss:0.706, D-Acc:48.000, G-Loss:0.746
# Epoch:13, Step:450, D-Loss:0.627, D-Acc:75.000, G-Loss:0.806
# Epoch:14, Step:0, D-Loss:0.631, D-Acc:76.000, G-Loss:0.794
# Epoch:14, Step:50, D-Loss:0.709, D-Acc:45.000, G-Loss:0.747
# Epoch:14, Step:100, D-Loss:0.763, D-Acc:30.000, G-Loss:0.693
# Epoch:14, Step:150, D-Loss:0.762, D-Acc:32.000, G-Loss:0.689
# Epoch:14, Step:200, D-Loss:0.698, D-Acc:46.000, G-Loss:0.733
# Epoch:14, Step:250, D-Loss:0.650, D-Acc:72.000, G-Loss:0.823
# Epoch:14, Step:300, D-Loss:0.666, D-Acc:73.000, G-Loss:0.790
# Epoch:14, Step:350, D-Loss:0.696, D-Acc:50.000, G-Loss:0.732
# Epoch:14, Step:400, D-Loss:0.695, D-Acc:41.000, G-Loss:0.711
# Epoch:14, Step:450, D-Loss:0.703, D-Acc:50.000, G-Loss:0.729
# Epoch:15, Step:0, D-Loss:0.666, D-Acc:70.000, G-Loss:0.757
# Epoch:15, Step:50, D-Loss:0.703, D-Acc:62.000, G-Loss:0.755
# Epoch:15, Step:100, D-Loss:0.724, D-Acc:50.000, G-Loss:0.730
# Epoch:15, Step:150, D-Loss:0.700, D-Acc:55.000, G-Loss:0.757
# Epoch:15, Step:200, D-Loss:0.698, D-Acc:60.000, G-Loss:0.733
# Epoch:15, Step:250, D-Loss:0.699, D-Acc:48.000, G-Loss:0.725
# Epoch:15, Step:300, D-Loss:0.702, D-Acc:52.000, G-Loss:0.747
# Epoch:15, Step:350, D-Loss:0.724, D-Acc:41.000, G-Loss:0.712
# Epoch:15, Step:400, D-Loss:0.698, D-Acc:52.000, G-Loss:0.735
# Epoch:15, Step:450, D-Loss:0.659, D-Acc:69.000, G-Loss:0.807
# Epoch:16, Step:0, D-Loss:0.736, D-Acc:31.000, G-Loss:0.703
# Epoch:16, Step:50, D-Loss:0.701, D-Acc:47.000, G-Loss:0.722
# Epoch:16, Step:100, D-Loss:0.699, D-Acc:53.000, G-Loss:0.750
# Epoch:16, Step:150, D-Loss:0.689, D-Acc:51.000, G-Loss:0.755
# Epoch:16, Step:200, D-Loss:0.754, D-Acc:47.000, G-Loss:0.720
# Epoch:16, Step:250, D-Loss:0.754, D-Acc:35.000, G-Loss:0.707
# Epoch:16, Step:300, D-Loss:0.677, D-Acc:54.000, G-Loss:0.752
# Epoch:16, Step:350, D-Loss:0.683, D-Acc:48.000, G-Loss:0.728
# Epoch:16, Step:400, D-Loss:0.695, D-Acc:66.000, G-Loss:0.778
# Epoch:16, Step:450, D-Loss:0.738, D-Acc:32.000, G-Loss:0.746
# Epoch:17, Step:0, D-Loss:0.721, D-Acc:59.000, G-Loss:0.783
# Epoch:17, Step:50, D-Loss:0.702, D-Acc:56.000, G-Loss:0.768
# Epoch:17, Step:100, D-Loss:0.737, D-Acc:37.000, G-Loss:0.704
# Epoch:17, Step:150, D-Loss:0.723, D-Acc:40.000, G-Loss:0.719
# Epoch:17, Step:200, D-Loss:0.707, D-Acc:46.000, G-Loss:0.718
# Epoch:17, Step:250, D-Loss:0.687, D-Acc:59.000, G-Loss:0.733
# Epoch:17, Step:300, D-Loss:0.697, D-Acc:50.000, G-Loss:0.742
# Epoch:17, Step:350, D-Loss:0.728, D-Acc:48.000, G-Loss:0.737
# Epoch:17, Step:400, D-Loss:0.712, D-Acc:52.000, G-Loss:0.741
# Epoch:17, Step:450, D-Loss:0.722, D-Acc:48.000, G-Loss:0.747
# Epoch:18, Step:0, D-Loss:0.734, D-Acc:43.000, G-Loss:0.728
# Epoch:18, Step:50, D-Loss:0.661, D-Acc:71.000, G-Loss:0.784
# Epoch:18, Step:100, D-Loss:0.747, D-Acc:43.000, G-Loss:0.734
# Epoch:18, Step:150, D-Loss:0.675, D-Acc:54.000, G-Loss:0.734
# Epoch:18, Step:200, D-Loss:0.720, D-Acc:39.000, G-Loss:0.719
# Epoch:18, Step:250, D-Loss:0.713, D-Acc:38.000, G-Loss:0.738
# Epoch:18, Step:300, D-Loss:0.729, D-Acc:49.000, G-Loss:0.724
# Epoch:18, Step:350, D-Loss:0.718, D-Acc:56.000, G-Loss:0.761
# Epoch:18, Step:400, D-Loss:0.690, D-Acc:60.000, G-Loss:0.767
# Epoch:18, Step:450, D-Loss:0.683, D-Acc:56.000, G-Loss:0.755
# Epoch:19, Step:0, D-Loss:0.722, D-Acc:36.000, G-Loss:0.716
# Epoch:19, Step:50, D-Loss:0.707, D-Acc:39.000, G-Loss:0.723
# Epoch:19, Step:100, D-Loss:0.676, D-Acc:71.000, G-Loss:0.791
# Epoch:19, Step:150, D-Loss:0.696, D-Acc:51.000, G-Loss:0.749
# Epoch:19, Step:200, D-Loss:0.694, D-Acc:56.000, G-Loss:0.766
# Epoch:19, Step:250, D-Loss:0.702, D-Acc:56.000, G-Loss:0.748
# Epoch:19, Step:300, D-Loss:0.716, D-Acc:39.000, G-Loss:0.718
# Epoch:19, Step:350, D-Loss:0.740, D-Acc:40.000, G-Loss:0.717
# Epoch:19, Step:400, D-Loss:0.663, D-Acc:67.000, G-Loss:0.803
# Epoch:19, Step:450, D-Loss:0.714, D-Acc:39.000, G-Loss:0.710
# Epoch:20, Step:0, D-Loss:0.706, D-Acc:54.000, G-Loss:0.744
# Epoch:20, Step:50, D-Loss:0.750, D-Acc:30.000, G-Loss:0.676
# Epoch:20, Step:100, D-Loss:0.732, D-Acc:49.000, G-Loss:0.738
# Epoch:20, Step:150, D-Loss:0.679, D-Acc:69.000, G-Loss:0.803
# Epoch:20, Step:200, D-Loss:0.671, D-Acc:70.000, G-Loss:0.826
# Epoch:20, Step:250, D-Loss:0.689, D-Acc:58.000, G-Loss:0.746
# Epoch:20, Step:300, D-Loss:0.709, D-Acc:45.000, G-Loss:0.731
# Epoch:20, Step:350, D-Loss:0.732, D-Acc:36.000, G-Loss:0.692
# Epoch:20, Step:400, D-Loss:0.697, D-Acc:55.000, G-Loss:0.733
# Epoch:20, Step:450, D-Loss:0.670, D-Acc:65.000, G-Loss:0.759
# Epoch:21, Step:0, D-Loss:0.699, D-Acc:41.000, G-Loss:0.726
# Epoch:21, Step:50, D-Loss:0.710, D-Acc:49.000, G-Loss:0.749
# Epoch:21, Step:100, D-Loss:0.710, D-Acc:51.000, G-Loss:0.735
# Epoch:21, Step:150, D-Loss:0.696, D-Acc:53.000, G-Loss:0.759
# Epoch:21, Step:200, D-Loss:0.675, D-Acc:56.000, G-Loss:0.762
# Epoch:21, Step:250, D-Loss:0.670, D-Acc:61.000, G-Loss:0.774
# Epoch:21, Step:300, D-Loss:0.664, D-Acc:63.000, G-Loss:0.774
# Epoch:21, Step:350, D-Loss:0.733, D-Acc:38.000, G-Loss:0.728
# Epoch:21, Step:400, D-Loss:0.729, D-Acc:37.000, G-Loss:0.721
# Epoch:21, Step:450, D-Loss:0.715, D-Acc:55.000, G-Loss:0.747
# Epoch:22, Step:0, D-Loss:0.669, D-Acc:59.000, G-Loss:0.759
# Epoch:22, Step:50, D-Loss:0.776, D-Acc:36.000, G-Loss:0.733
# Epoch:22, Step:100, D-Loss:0.749, D-Acc:39.000, G-Loss:0.726
# Epoch:22, Step:150, D-Loss:0.650, D-Acc:70.000, G-Loss:0.795
# Epoch:22, Step:200, D-Loss:0.728, D-Acc:53.000, G-Loss:0.734
# Epoch:22, Step:250, D-Loss:0.697, D-Acc:58.000, G-Loss:0.742
# Epoch:22, Step:300, D-Loss:0.697, D-Acc:55.000, G-Loss:0.738
# Epoch:22, Step:350, D-Loss:0.717, D-Acc:56.000, G-Loss:0.742
# Epoch:22, Step:400, D-Loss:0.682, D-Acc:62.000, G-Loss:0.754
# Epoch:22, Step:450, D-Loss:0.681, D-Acc:68.000, G-Loss:0.776
# Epoch:23, Step:0, D-Loss:0.709, D-Acc:45.000, G-Loss:0.729
# Epoch:23, Step:50, D-Loss:0.715, D-Acc:38.000, G-Loss:0.713
# Epoch:23, Step:100, D-Loss:0.690, D-Acc:57.000, G-Loss:0.733
# Epoch:23, Step:150, D-Loss:0.690, D-Acc:54.000, G-Loss:0.737
# Epoch:23, Step:200, D-Loss:0.707, D-Acc:52.000, G-Loss:0.751
# Epoch:23, Step:250, D-Loss:0.735, D-Acc:49.000, G-Loss:0.748
# Epoch:23, Step:300, D-Loss:0.736, D-Acc:43.000, G-Loss:0.730
# Epoch:23, Step:350, D-Loss:0.729, D-Acc:32.000, G-Loss:0.725
# Epoch:23, Step:400, D-Loss:0.660, D-Acc:68.000, G-Loss:0.780
# Epoch:23, Step:450, D-Loss:0.682, D-Acc:58.000, G-Loss:0.741
# Epoch:24, Step:0, D-Loss:0.703, D-Acc:54.000, G-Loss:0.745
# Epoch:24, Step:50, D-Loss:0.659, D-Acc:73.000, G-Loss:0.771
# Epoch:24, Step:100, D-Loss:0.703, D-Acc:55.000, G-Loss:0.726
# Epoch:24, Step:150, D-Loss:0.753, D-Acc:34.000, G-Loss:0.694
# Epoch:24, Step:200, D-Loss:0.700, D-Acc:55.000, G-Loss:0.748
# Epoch:24, Step:250, D-Loss:0.689, D-Acc:58.000, G-Loss:0.762
# Epoch:24, Step:300, D-Loss:0.726, D-Acc:43.000, G-Loss:0.732
# Epoch:24, Step:350, D-Loss:0.701, D-Acc:59.000, G-Loss:0.768
# Epoch:24, Step:400, D-Loss:0.721, D-Acc:48.000, G-Loss:0.739
# Epoch:24, Step:450, D-Loss:0.702, D-Acc:48.000, G-Loss:0.731
# Epoch:25, Step:0, D-Loss:0.633, D-Acc:70.000, G-Loss:0.768
# Epoch:25, Step:50, D-Loss:0.656, D-Acc:67.000, G-Loss:0.747
# Epoch:25, Step:100, D-Loss:0.701, D-Acc:47.000, G-Loss:0.747
# Epoch:25, Step:150, D-Loss:0.703, D-Acc:51.000, G-Loss:0.751
# Epoch:25, Step:200, D-Loss:0.742, D-Acc:28.000, G-Loss:0.681
# Epoch:25, Step:250, D-Loss:0.709, D-Acc:52.000, G-Loss:0.738
# Epoch:25, Step:300, D-Loss:0.754, D-Acc:35.000, G-Loss:0.718
# Epoch:25, Step:350, D-Loss:0.679, D-Acc:69.000, G-Loss:0.788
# Epoch:25, Step:400, D-Loss:0.631, D-Acc:77.000, G-Loss:0.769
# Epoch:25, Step:450, D-Loss:0.696, D-Acc:45.000, G-Loss:0.696
# Epoch:26, Step:0, D-Loss:0.769, D-Acc:22.000, G-Loss:0.679
# Epoch:26, Step:50, D-Loss:0.680, D-Acc:60.000, G-Loss:0.772
# Epoch:26, Step:100, D-Loss:0.651, D-Acc:71.000, G-Loss:0.788
# Epoch:26, Step:150, D-Loss:0.670, D-Acc:52.000, G-Loss:0.784
# Epoch:26, Step:200, D-Loss:0.706, D-Acc:41.000, G-Loss:0.710
# Epoch:26, Step:250, D-Loss:0.712, D-Acc:34.000, G-Loss:0.711
# Epoch:26, Step:300, D-Loss:0.696, D-Acc:61.000, G-Loss:0.746
# Epoch:26, Step:350, D-Loss:0.680, D-Acc:55.000, G-Loss:0.740
# Epoch:26, Step:400, D-Loss:0.715, D-Acc:43.000, G-Loss:0.733
# Epoch:26, Step:450, D-Loss:0.691, D-Acc:71.000, G-Loss:0.779
# Epoch:27, Step:0, D-Loss:0.699, D-Acc:46.000, G-Loss:0.757
# Epoch:27, Step:50, D-Loss:0.722, D-Acc:43.000, G-Loss:0.718
# Epoch:27, Step:100, D-Loss:0.668, D-Acc:63.000, G-Loss:0.762
# Epoch:27, Step:150, D-Loss:0.698, D-Acc:53.000, G-Loss:0.738
# Epoch:27, Step:200, D-Loss:0.731, D-Acc:36.000, G-Loss:0.704
# Epoch:27, Step:250, D-Loss:0.706, D-Acc:56.000, G-Loss:0.765
# Epoch:27, Step:300, D-Loss:0.656, D-Acc:72.000, G-Loss:0.779
# Epoch:27, Step:350, D-Loss:0.674, D-Acc:64.000, G-Loss:0.765
# Epoch:27, Step:400, D-Loss:0.739, D-Acc:45.000, G-Loss:0.723
# Epoch:27, Step:450, D-Loss:0.687, D-Acc:53.000, G-Loss:0.745
# Epoch:28, Step:0, D-Loss:0.737, D-Acc:35.000, G-Loss:0.700
# Epoch:28, Step:50, D-Loss:0.665, D-Acc:60.000, G-Loss:0.778
# Epoch:28, Step:100, D-Loss:0.739, D-Acc:31.000, G-Loss:0.718
# Epoch:28, Step:150, D-Loss:0.746, D-Acc:37.000, G-Loss:0.726
# Epoch:28, Step:200, D-Loss:0.690, D-Acc:43.000, G-Loss:0.715
# Epoch:28, Step:250, D-Loss:0.682, D-Acc:71.000, G-Loss:0.795
# Epoch:28, Step:300, D-Loss:0.716, D-Acc:42.000, G-Loss:0.694
# Epoch:28, Step:350, D-Loss:0.752, D-Acc:45.000, G-Loss:0.742
# Epoch:28, Step:400, D-Loss:0.662, D-Acc:72.000, G-Loss:0.806
# Epoch:28, Step:450, D-Loss:0.646, D-Acc:69.000, G-Loss:0.777
# Epoch:29, Step:0, D-Loss:0.725, D-Acc:41.000, G-Loss:0.707
# Epoch:29, Step:50, D-Loss:0.703, D-Acc:46.000, G-Loss:0.743
# Epoch:29, Step:100, D-Loss:0.670, D-Acc:61.000, G-Loss:0.753
# Epoch:29, Step:150, D-Loss:0.739, D-Acc:35.000, G-Loss:0.716
# Epoch:29, Step:200, D-Loss:0.702, D-Acc:53.000, G-Loss:0.735
# Epoch:29, Step:250, D-Loss:0.714, D-Acc:42.000, G-Loss:0.715
# Epoch:29, Step:300, D-Loss:0.671, D-Acc:64.000, G-Loss:0.755
# Epoch:29, Step:350, D-Loss:0.714, D-Acc:46.000, G-Loss:0.737
# Epoch:29, Step:400, D-Loss:0.713, D-Acc:48.000, G-Loss:0.746
# Epoch:29, Step:450, D-Loss:0.688, D-Acc:59.000, G-Loss:0.775
# Epoch:30, Step:0, D-Loss:0.691, D-Acc:64.000, G-Loss:0.777
# Epoch:30, Step:50, D-Loss:0.729, D-Acc:41.000, G-Loss:0.702
# Epoch:30, Step:100, D-Loss:0.653, D-Acc:57.000, G-Loss:0.737
# Epoch:30, Step:150, D-Loss:0.710, D-Acc:43.000, G-Loss:0.722
# Epoch:30, Step:200, D-Loss:0.658, D-Acc:67.000, G-Loss:0.744
# Epoch:30, Step:250, D-Loss:0.710, D-Acc:38.000, G-Loss:0.700
# Epoch:30, Step:300, D-Loss:0.677, D-Acc:59.000, G-Loss:0.749
# Epoch:30, Step:350, D-Loss:0.700, D-Acc:57.000, G-Loss:0.761
# Epoch:30, Step:400, D-Loss:0.792, D-Acc:27.000, G-Loss:0.701
# Epoch:30, Step:450, D-Loss:0.731, D-Acc:48.000, G-Loss:0.737
# Epoch:31, Step:0, D-Loss:0.671, D-Acc:69.000, G-Loss:0.821
# Epoch:31, Step:50, D-Loss:0.695, D-Acc:59.000, G-Loss:0.767
# Epoch:31, Step:100, D-Loss:0.711, D-Acc:43.000, G-Loss:0.731
# Epoch:31, Step:150, D-Loss:0.706, D-Acc:42.000, G-Loss:0.697
# Epoch:31, Step:200, D-Loss:0.675, D-Acc:56.000, G-Loss:0.758
# Epoch:31, Step:250, D-Loss:0.676, D-Acc:52.000, G-Loss:0.728
# Epoch:31, Step:300, D-Loss:0.725, D-Acc:41.000, G-Loss:0.695
# Epoch:31, Step:350, D-Loss:0.748, D-Acc:32.000, G-Loss:0.704
# Epoch:31, Step:400, D-Loss:0.745, D-Acc:46.000, G-Loss:0.737
# Epoch:31, Step:450, D-Loss:0.679, D-Acc:65.000, G-Loss:0.798
# Epoch:32, Step:0, D-Loss:0.634, D-Acc:77.000, G-Loss:0.797
# Epoch:32, Step:50, D-Loss:0.666, D-Acc:59.000, G-Loss:0.752
# Epoch:32, Step:100, D-Loss:0.747, D-Acc:31.000, G-Loss:0.708
# Epoch:32, Step:150, D-Loss:0.715, D-Acc:42.000, G-Loss:0.730
# Epoch:32, Step:200, D-Loss:0.687, D-Acc:62.000, G-Loss:0.747
# Epoch:32, Step:250, D-Loss:0.677, D-Acc:65.000, G-Loss:0.778
# Epoch:32, Step:300, D-Loss:0.725, D-Acc:47.000, G-Loss:0.735
# Epoch:32, Step:350, D-Loss:0.759, D-Acc:27.000, G-Loss:0.706
# Epoch:32, Step:400, D-Loss:0.716, D-Acc:49.000, G-Loss:0.722
# Epoch:32, Step:450, D-Loss:0.678, D-Acc:61.000, G-Loss:0.753
# Epoch:33, Step:0, D-Loss:0.716, D-Acc:48.000, G-Loss:0.743
# Epoch:33, Step:50, D-Loss:0.671, D-Acc:58.000, G-Loss:0.743
# Epoch:33, Step:100, D-Loss:0.730, D-Acc:44.000, G-Loss:0.706
# Epoch:33, Step:150, D-Loss:0.684, D-Acc:69.000, G-Loss:0.760
# Epoch:33, Step:200, D-Loss:0.709, D-Acc:50.000, G-Loss:0.730
# Epoch:33, Step:250, D-Loss:0.769, D-Acc:42.000, G-Loss:0.717
# Epoch:33, Step:300, D-Loss:0.752, D-Acc:33.000, G-Loss:0.715
# Epoch:33, Step:350, D-Loss:0.648, D-Acc:71.000, G-Loss:0.785
# Epoch:33, Step:400, D-Loss:0.666, D-Acc:63.000, G-Loss:0.741
# Epoch:33, Step:450, D-Loss:0.714, D-Acc:41.000, G-Loss:0.716
# Epoch:34, Step:0, D-Loss:0.694, D-Acc:58.000, G-Loss:0.748
# Epoch:34, Step:50, D-Loss:0.728, D-Acc:39.000, G-Loss:0.694
# Epoch:34, Step:100, D-Loss:0.657, D-Acc:69.000, G-Loss:0.767
# Epoch:34, Step:150, D-Loss:0.693, D-Acc:61.000, G-Loss:0.748
# Epoch:34, Step:200, D-Loss:0.714, D-Acc:44.000, G-Loss:0.740
# Epoch:34, Step:250, D-Loss:0.671, D-Acc:69.000, G-Loss:0.752
# Epoch:34, Step:300, D-Loss:0.697, D-Acc:56.000, G-Loss:0.741
# Epoch:34, Step:350, D-Loss:0.721, D-Acc:39.000, G-Loss:0.722
# Epoch:34, Step:400, D-Loss:0.676, D-Acc:65.000, G-Loss:0.755
# Epoch:34, Step:450, D-Loss:0.717, D-Acc:33.000, G-Loss:0.690
# Epoch:35, Step:0, D-Loss:0.718, D-Acc:51.000, G-Loss:0.752
# Epoch:35, Step:50, D-Loss:0.722, D-Acc:39.000, G-Loss:0.719
# Epoch:35, Step:100, D-Loss:0.670, D-Acc:60.000, G-Loss:0.743
# Epoch:35, Step:150, D-Loss:0.677, D-Acc:56.000, G-Loss:0.768
# Epoch:35, Step:200, D-Loss:0.661, D-Acc:71.000, G-Loss:0.777
# Epoch:35, Step:250, D-Loss:0.717, D-Acc:34.000, G-Loss:0.689
# Epoch:35, Step:300, D-Loss:0.725, D-Acc:45.000, G-Loss:0.728
# Epoch:35, Step:350, D-Loss:0.691, D-Acc:58.000, G-Loss:0.748
# Epoch:35, Step:400, D-Loss:0.681, D-Acc:67.000, G-Loss:0.791
# Epoch:35, Step:450, D-Loss:0.704, D-Acc:50.000, G-Loss:0.746
# Epoch:36, Step:0, D-Loss:0.686, D-Acc:63.000, G-Loss:0.759
# Epoch:36, Step:50, D-Loss:0.747, D-Acc:36.000, G-Loss:0.718
# Epoch:36, Step:100, D-Loss:0.715, D-Acc:32.000, G-Loss:0.702
# Epoch:36, Step:150, D-Loss:0.664, D-Acc:70.000, G-Loss:0.767
# Epoch:36, Step:200, D-Loss:0.664, D-Acc:69.000, G-Loss:0.784
# Epoch:36, Step:250, D-Loss:0.723, D-Acc:45.000, G-Loss:0.721
# Epoch:36, Step:300, D-Loss:0.678, D-Acc:63.000, G-Loss:0.732
# Epoch:36, Step:350, D-Loss:0.745, D-Acc:32.000, G-Loss:0.722
# Epoch:36, Step:400, D-Loss:0.729, D-Acc:41.000, G-Loss:0.727
# Epoch:36, Step:450, D-Loss:0.686, D-Acc:51.000, G-Loss:0.728
# Epoch:37, Step:0, D-Loss:0.699, D-Acc:43.000, G-Loss:0.723
# Epoch:37, Step:50, D-Loss:0.731, D-Acc:39.000, G-Loss:0.697
# Epoch:37, Step:100, D-Loss:0.690, D-Acc:65.000, G-Loss:0.759
# Epoch:37, Step:150, D-Loss:0.672, D-Acc:67.000, G-Loss:0.773
# Epoch:37, Step:200, D-Loss:0.717, D-Acc:42.000, G-Loss:0.717
# Epoch:37, Step:250, D-Loss:0.706, D-Acc:35.000, G-Loss:0.703
# Epoch:37, Step:300, D-Loss:0.689, D-Acc:53.000, G-Loss:0.745
# Epoch:37, Step:350, D-Loss:0.700, D-Acc:57.000, G-Loss:0.754
# Epoch:37, Step:400, D-Loss:0.649, D-Acc:77.000, G-Loss:0.794
# Epoch:37, Step:450, D-Loss:0.696, D-Acc:53.000, G-Loss:0.727
# Epoch:38, Step:0, D-Loss:0.756, D-Acc:26.000, G-Loss:0.682
# Epoch:38, Step:50, D-Loss:0.734, D-Acc:41.000, G-Loss:0.712
# Epoch:38, Step:100, D-Loss:0.680, D-Acc:52.000, G-Loss:0.748
# Epoch:38, Step:150, D-Loss:0.656, D-Acc:70.000, G-Loss:0.779
# Epoch:38, Step:200, D-Loss:0.725, D-Acc:41.000, G-Loss:0.721
# Epoch:38, Step:250, D-Loss:0.715, D-Acc:55.000, G-Loss:0.741
# Epoch:38, Step:300, D-Loss:0.690, D-Acc:55.000, G-Loss:0.737
# Epoch:38, Step:350, D-Loss:0.681, D-Acc:53.000, G-Loss:0.749
# Epoch:38, Step:400, D-Loss:0.680, D-Acc:63.000, G-Loss:0.758
# Epoch:38, Step:450, D-Loss:0.708, D-Acc:37.000, G-Loss:0.726
# Epoch:39, Step:0, D-Loss:0.701, D-Acc:46.000, G-Loss:0.751
# Epoch:39, Step:50, D-Loss:0.679, D-Acc:57.000, G-Loss:0.753
# Epoch:39, Step:100, D-Loss:0.686, D-Acc:49.000, G-Loss:0.730
# Epoch:39, Step:150, D-Loss:0.751, D-Acc:33.000, G-Loss:0.685
# Epoch:39, Step:200, D-Loss:0.742, D-Acc:35.000, G-Loss:0.704
# Epoch:39, Step:250, D-Loss:0.740, D-Acc:30.000, G-Loss:0.677
# Epoch:39, Step:300, D-Loss:0.686, D-Acc:62.000, G-Loss:0.757
# Epoch:39, Step:350, D-Loss:0.689, D-Acc:60.000, G-Loss:0.758
# Epoch:39, Step:400, D-Loss:0.657, D-Acc:69.000, G-Loss:0.759
# Epoch:39, Step:450, D-Loss:0.736, D-Acc:38.000, G-Loss:0.708
# Epoch:40, Step:0, D-Loss:0.660, D-Acc:65.000, G-Loss:0.782
# Epoch:40, Step:50, D-Loss:0.708, D-Acc:41.000, G-Loss:0.708
# Epoch:40, Step:100, D-Loss:0.745, D-Acc:30.000, G-Loss:0.703
# Epoch:40, Step:150, D-Loss:0.729, D-Acc:45.000, G-Loss:0.737
# Epoch:40, Step:200, D-Loss:0.710, D-Acc:52.000, G-Loss:0.735
# Epoch:40, Step:250, D-Loss:0.712, D-Acc:57.000, G-Loss:0.772
# Epoch:40, Step:300, D-Loss:0.744, D-Acc:41.000, G-Loss:0.713
# Epoch:40, Step:350, D-Loss:0.668, D-Acc:69.000, G-Loss:0.770
# Epoch:40, Step:400, D-Loss:0.711, D-Acc:36.000, G-Loss:0.689
# Epoch:40, Step:450, D-Loss:0.684, D-Acc:58.000, G-Loss:0.737
# Epoch:41, Step:0, D-Loss:0.624, D-Acc:79.000, G-Loss:0.785
# Epoch:41, Step:50, D-Loss:0.689, D-Acc:50.000, G-Loss:0.719
# Epoch:41, Step:100, D-Loss:0.741, D-Acc:26.000, G-Loss:0.670
# Epoch:41, Step:150, D-Loss:0.736, D-Acc:31.000, G-Loss:0.687
# Epoch:41, Step:200, D-Loss:0.674, D-Acc:67.000, G-Loss:0.776
# Epoch:41, Step:250, D-Loss:0.682, D-Acc:65.000, G-Loss:0.785
# Epoch:41, Step:300, D-Loss:0.719, D-Acc:42.000, G-Loss:0.723
# Epoch:41, Step:350, D-Loss:0.756, D-Acc:29.000, G-Loss:0.701
# Epoch:41, Step:400, D-Loss:0.723, D-Acc:52.000, G-Loss:0.746
# Epoch:41, Step:450, D-Loss:0.746, D-Acc:43.000, G-Loss:0.719
# Epoch:42, Step:0, D-Loss:0.694, D-Acc:54.000, G-Loss:0.749
# Epoch:42, Step:50, D-Loss:0.668, D-Acc:65.000, G-Loss:0.761
# Epoch:42, Step:100, D-Loss:0.698, D-Acc:55.000, G-Loss:0.742
# Epoch:42, Step:150, D-Loss:0.712, D-Acc:53.000, G-Loss:0.749
# Epoch:42, Step:200, D-Loss:0.703, D-Acc:43.000, G-Loss:0.702
# Epoch:42, Step:250, D-Loss:0.689, D-Acc:53.000, G-Loss:0.742
# Epoch:42, Step:300, D-Loss:0.690, D-Acc:45.000, G-Loss:0.710
# Epoch:42, Step:350, D-Loss:0.724, D-Acc:44.000, G-Loss:0.726
# Epoch:42, Step:400, D-Loss:0.658, D-Acc:68.000, G-Loss:0.748
# Epoch:42, Step:450, D-Loss:0.704, D-Acc:50.000, G-Loss:0.721
# Epoch:43, Step:0, D-Loss:0.697, D-Acc:49.000, G-Loss:0.731
# Epoch:43, Step:50, D-Loss:0.719, D-Acc:40.000, G-Loss:0.724
# Epoch:43, Step:100, D-Loss:0.718, D-Acc:47.000, G-Loss:0.740
# Epoch:43, Step:150, D-Loss:0.702, D-Acc:56.000, G-Loss:0.737
# Epoch:43, Step:200, D-Loss:0.692, D-Acc:43.000, G-Loss:0.728
# Epoch:43, Step:250, D-Loss:0.657, D-Acc:70.000, G-Loss:0.739
# Epoch:43, Step:300, D-Loss:0.696, D-Acc:47.000, G-Loss:0.713
# Epoch:43, Step:350, D-Loss:0.690, D-Acc:46.000, G-Loss:0.702
# Epoch:43, Step:400, D-Loss:0.723, D-Acc:35.000, G-Loss:0.700
# Epoch:43, Step:450, D-Loss:0.711, D-Acc:42.000, G-Loss:0.705
# Epoch:44, Step:0, D-Loss:0.669, D-Acc:69.000, G-Loss:0.752
# Epoch:44, Step:50, D-Loss:0.678, D-Acc:59.000, G-Loss:0.752
# Epoch:44, Step:100, D-Loss:0.694, D-Acc:47.000, G-Loss:0.724
# Epoch:44, Step:150, D-Loss:0.693, D-Acc:56.000, G-Loss:0.749
# Epoch:44, Step:200, D-Loss:0.706, D-Acc:46.000, G-Loss:0.732
# Epoch:44, Step:250, D-Loss:0.712, D-Acc:44.000, G-Loss:0.715
# Epoch:44, Step:300, D-Loss:0.667, D-Acc:72.000, G-Loss:0.782
# Epoch:44, Step:350, D-Loss:0.713, D-Acc:44.000, G-Loss:0.716
# Epoch:44, Step:400, D-Loss:0.676, D-Acc:68.000, G-Loss:0.768
# Epoch:44, Step:450, D-Loss:0.688, D-Acc:56.000, G-Loss:0.737
# Epoch:45, Step:0, D-Loss:0.698, D-Acc:57.000, G-Loss:0.750
# Epoch:45, Step:50, D-Loss:0.723, D-Acc:31.000, G-Loss:0.695
# Epoch:45, Step:100, D-Loss:0.702, D-Acc:57.000, G-Loss:0.726
# Epoch:45, Step:150, D-Loss:0.662, D-Acc:64.000, G-Loss:0.753
# Epoch:45, Step:200, D-Loss:0.711, D-Acc:46.000, G-Loss:0.701
# Epoch:45, Step:250, D-Loss:0.727, D-Acc:39.000, G-Loss:0.720
# Epoch:45, Step:300, D-Loss:0.715, D-Acc:45.000, G-Loss:0.718
# Epoch:45, Step:350, D-Loss:0.675, D-Acc:61.000, G-Loss:0.732
# Epoch:45, Step:400, D-Loss:0.707, D-Acc:46.000, G-Loss:0.720
# Epoch:45, Step:450, D-Loss:0.701, D-Acc:56.000, G-Loss:0.752
# Epoch:46, Step:0, D-Loss:0.701, D-Acc:45.000, G-Loss:0.730
# Epoch:46, Step:50, D-Loss:0.707, D-Acc:52.000, G-Loss:0.731
# Epoch:46, Step:100, D-Loss:0.655, D-Acc:73.000, G-Loss:0.806
# Epoch:46, Step:150, D-Loss:0.723, D-Acc:35.000, G-Loss:0.690
# Epoch:46, Step:200, D-Loss:0.692, D-Acc:58.000, G-Loss:0.741
# Epoch:46, Step:250, D-Loss:0.715, D-Acc:34.000, G-Loss:0.697
# Epoch:46, Step:300, D-Loss:0.729, D-Acc:34.000, G-Loss:0.722
# Epoch:46, Step:350, D-Loss:0.715, D-Acc:46.000, G-Loss:0.729
# Epoch:46, Step:400, D-Loss:0.771, D-Acc:34.000, G-Loss:0.726
# Epoch:46, Step:450, D-Loss:0.712, D-Acc:49.000, G-Loss:0.733
# Epoch:47, Step:0, D-Loss:0.698, D-Acc:66.000, G-Loss:0.771
# Epoch:47, Step:50, D-Loss:0.668, D-Acc:54.000, G-Loss:0.724
# Epoch:47, Step:100, D-Loss:0.694, D-Acc:56.000, G-Loss:0.729
# Epoch:47, Step:150, D-Loss:0.665, D-Acc:69.000, G-Loss:0.736
# Epoch:47, Step:200, D-Loss:0.726, D-Acc:38.000, G-Loss:0.693
# Epoch:47, Step:250, D-Loss:0.749, D-Acc:30.000, G-Loss:0.712
# Epoch:47, Step:300, D-Loss:0.680, D-Acc:61.000, G-Loss:0.751
# Epoch:47, Step:350, D-Loss:0.657, D-Acc:75.000, G-Loss:0.773
# Epoch:47, Step:400, D-Loss:0.739, D-Acc:30.000, G-Loss:0.672
# Epoch:47, Step:450, D-Loss:0.732, D-Acc:35.000, G-Loss:0.713
# Epoch:48, Step:0, D-Loss:0.679, D-Acc:66.000, G-Loss:0.774
# Epoch:48, Step:50, D-Loss:0.637, D-Acc:78.000, G-Loss:0.767
# Epoch:48, Step:100, D-Loss:0.712, D-Acc:45.000, G-Loss:0.711
# Epoch:48, Step:150, D-Loss:0.711, D-Acc:51.000, G-Loss:0.715
# Epoch:48, Step:200, D-Loss:0.718, D-Acc:35.000, G-Loss:0.716
# Epoch:48, Step:250, D-Loss:0.690, D-Acc:51.000, G-Loss:0.751
# Epoch:48, Step:300, D-Loss:0.675, D-Acc:66.000, G-Loss:0.757
# Epoch:48, Step:350, D-Loss:0.746, D-Acc:28.000, G-Loss:0.687
# Epoch:48, Step:400, D-Loss:0.690, D-Acc:58.000, G-Loss:0.756
# Epoch:48, Step:450, D-Loss:0.654, D-Acc:71.000, G-Loss:0.745
# Epoch:49, Step:0, D-Loss:0.719, D-Acc:30.000, G-Loss:0.688
# Epoch:49, Step:50, D-Loss:0.696, D-Acc:60.000, G-Loss:0.737
# Epoch:49, Step:100, D-Loss:0.676, D-Acc:71.000, G-Loss:0.751
# Epoch:49, Step:150, D-Loss:0.714, D-Acc:47.000, G-Loss:0.718
# Epoch:49, Step:200, D-Loss:0.730, D-Acc:35.000, G-Loss:0.698
# Epoch:49, Step:250, D-Loss:0.661, D-Acc:68.000, G-Loss:0.786
# Epoch:49, Step:300, D-Loss:0.674, D-Acc:48.000, G-Loss:0.722
# Epoch:49, Step:350, D-Loss:0.690, D-Acc:56.000, G-Loss:0.742
# Epoch:49, Step:400, D-Loss:0.732, D-Acc:31.000, G-Loss:0.717
# Epoch:49, Step:450, D-Loss:0.670, D-Acc:73.000, G-Loss:0.767

# %%
steps = [i for i in range(len(losses_d))]
plt.figure(figsize=(10, 6))
plt.plot(losses_d[:5000])
plt.plot(losses_g[:5000])
plt.xlabel('Steps')
plt.ylabel('Loss Value')
plt.title("Mode Collapse: Loss Trends")
plt.legend(['Discriminator Loss', 'Generator Loss'])
plt.show()
